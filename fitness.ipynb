# %%
from fitness import *
from viz.viz import *

# bench = Exercise([Set(175, 6), Set(175, 5), Set(175, 4)], [5, 5], "bench_press")
# pullup = Exercise([Set(35, 6), Set(35, 4), Set(35, 4)], [5, 5], "pull_up")

squat = Exercise([Set(265, 5), Set(265, 5), Set(265, 5)], [5, 5], "squat")
deadlift = Exercise([Set(365, 2), Set(405, 2), Set(405, 1), Set(405, 1)], [5, 5, 5], "deadlift")
w = Workout(20221210, [squat, deadlift])

add_workout(w, True)

# %%
bench = Exercise([Set(185, 4), Set(185, 2), Set(185, 1)], [5, 5], "bench_press")
pullup = Exercise([Set(0, 10), Set(0, 6), Set(0, 5)], [3, 3], "pull_up")
w = Workout(20221211, [bench, pullup])

add_workout(w, True)

# %%
viz_exercise("pull_up", VOLUME)

# %%
viz_exercise("pull_up", MAX_REPS)

# %%
viz_exercise("deadlift", MAX_PER_SET_VOLUME)
