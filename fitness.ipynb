# %%
from fitness import *
from viz.viz import *

# bench = Exercise([Set(175, 6), Set(175, 5), Set(175, 4)], [5, 5], "bench_press")
# pullup = Exercise([Set(35, 6), Set(35, 4), Set(35, 4)], [5, 5], "pull_up")

squat = Exercise([Set(235, 5), Set(235, 5), Set(235, 5)], [4, 4], "squat")
deadlift = Exercise([Set(405, 3), Set(405, 2), Set(405, 1)], [5, 5], "deadlift")
w = Workout(20221227, [squat, deadlift])

add_workout(w, True)

# %%
squat = Exercise([Set(285, 5), Set(285, 5), Set(285, 4)], [5, 5], "squat")
bench = Exercise([Set(165, 8), Set(165, 8), Set(165, 5), Set(165, 2)], [3, 3, 3], "bench_press")
pullup = Exercise([Set(0, 8), Set(0, 6), Set(0, 5)], [2, 2], "pull_up")
w = Workout(20221231, [bench, pullup, squat])

add_workout(w, True)

# %%
bench = Exercise([Set(190, 5), Set(195, 5), Set(195, 5), Set(195, 4)], [5, 5, 5], "bench_press")
pullup = Exercise([Set(25, 5), Set(15, 5), Set(0, 4), Set(0, 4)], [2, 2, 2], "pull_up")
cp_db_row = Exercise([Set(70, 10), Set(70, 10), Set(70, 10), Set(70, 10)], [2,2,2], "cp_db_row")
w = Workout(20230402, [bench, pullup, cp_db_row])

add_workout(w, True)

# %%
deadlift = Exercise([Set(385, 2), Set(385, 2), Set(385, 1), Set(385, 1), Set(385, 1)], [5, 5, 5, 5], "deadlift")
w = Workout(20230401, [deadlift])

add_workout(w, True)

# %%
deadlift = Exercise([Set(385, 3), Set(385, 3), Set(385, 3), Set(385, 3)], [5, 5, 5], "deadlift")
w = Workout(20230212, [deadlift])

add_workout(w, True)

# %%
bench = Exercise([Set(175, 8), Set(175, 8), Set(175, 3), Set(155, 7)], [3, 3, 3], "bench_press")
pullup = Exercise([Set(20, 5), Set(20, 4), Set(20, 2), Set(0, 5)], [3, 3, 3], "pull_up")
w = Workout(20230205, [bench, pullup])

add_workout(w, True)

# %%
viz_exercise("bench_press", MAX_WEIGHT)

# %%
viz_exercise("pull_up", MAX_REPS)

# %%
viz_exercise("deadlift", MAX_PER_SET_VOLUME)
