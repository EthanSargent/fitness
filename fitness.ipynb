# %%
from fitness import *
from viz.viz import *

squat = Exercise([Set(255, 6), Set(255, 8), Set(255, 6)], [5, 5], "squat")
deadlift = Exercise([Set(385, 4), Set(385, 4), Set(385, 3)], [5, 5], "deadlift")
w = Workout(20221124, [squat, deadlift])

add_workout(w, True)

# %%
viz_exercise("deadlift", MAX_WEIGHT)

# %%
MAX_PER_SET_VOLUME = Metric(
    "max_per_set_volume",
    lambda ex: max([s.weight * s.reps for s in ex.sets]))
viz_exercise("deadlift", MAX_PER_SET_VOLUME)
