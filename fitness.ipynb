# %%
from fitness import *
from viz.viz import *

# %%
squat = Exercise([Set(255, 6), Set(255, 8), Set(255, 6)], [5, 5], "squat")
deadlift = Exercise([Set(385, 4), Set(385, 4), Set(385, 3)], [5, 5], "deadlift")
w4 = Workout(20221124, [squat, deadlift])

add_workout(w4, True)

# %%
pull_up = Exercise([Set(0, 10), Set(0, 7), Set(0, 4)], [3,3], "pull_up")
bench_press = Exercise([Set(175, 4), Set(175, 2), Set(175, 2), Set(175, 2)], [5, 5, 5], "bench_press")
w4 = Workout(20221120, [pull_up, bench_press])

add_workout(w4, True)

# %%
viz_exercise("bench_press", MAX_WEIGHT)

# %%
MAX_WEIGHT = Metric("max_weight", lambda ex: max([s.weight for s in ex.sets]))
VOLUME = Metric("volume_lbs", lambda ex: sum([s.weight * s.reps for s in ex.sets]))
MAX_PER_SET_VOLUME = Metric("max_per_set_volume", lambda ex: max([s.weight * s.reps for s in ex.sets]))
